# %%
import nfl_data_py as nfl

# %%
nfl.see_weekly_cols()
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'opponent_team', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
# ...

# %%
df = nfl.import_weekly_data([2024])
# Out:
# Downcasting floats.

# %%
df.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 1  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 2  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 3  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
# 4  00-0023459   A.Rodgers       Aaron Rodgers       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 1  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 2  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 3  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
# 4  https://static.www.nfl.com/image/upload/f_auto...         NYJ    2024
#
#    week season_type  ... receiving_first_downs  receiving_epa  \
# ...

# %%
df['player_display_name'][0]
# Out:
# 'Aaron Rodgers'

# %%
df.columns
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'opponent_team', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
# ...

# %%
df[df['player_display_name'] == 'Patrick Mahomes']
# Out:
#       player_id player_name player_display_name position position_group  \
# 977  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 978  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 979  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 980  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 981  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 982  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 983  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 984  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 985  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 986  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 987  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# 988  00-0033873   P.Mahomes     Patrick Mahomes       QB             QB
# ...

# %%
df_weekly = nfl.import_weekly_rosters([2024])

# %%
df_weekly[:17]
# Out:
#     season team position depth_chart_position  jersey_number status  \
# 0     2024  SEA       OL                    T           70.0    DEV
# 1     2024  SEA       OL                    T           70.0    DEV
# 2     2024  SEA       OL                    T           70.0    DEV
# 3     2024  SEA       OL                    T           70.0    DEV
# 4     2024  SEA       OL                    T           70.0    DEV
# 5     2024  SEA       OL                    T           70.0    DEV
# 6     2024  SEA       OL                    T           70.0    DEV
# 7     2024  SEA       OL                    T           70.0    DEV
# 8     2024  SEA       OL                    T           70.0    DEV
# 9     2024  SEA       OL                    T           70.0    DEV
# 10    2024  SEA       OL                    T           70.0    DEV
# 11    2024  SEA       OL                    T           70.0    DEV
# 12    2024  SEA       OL                    T           70.0    DEV
# ...

# %%
df_weekly['status_description_abbr'].unique()
# Out:
# array(['P07', 'P02', 'A01', 'R02', 'R01', 'R48', 'I01', 'R40', 'W03',
#        'E02', 'I02', 'R04', 'R33', 'R27', 'P04', 'R36', 'P10', 'P01',
#        'R05', 'R03', 'R49', 'R06', 'E01', 'P06', 'R23', 'P03', 'R47',
#        'W04', 'R34'], dtype=object)

# %%
df_weekly.columns
# Out:
# Index(['season', 'team', 'position', 'depth_chart_position', 'jersey_number',
#        'status', 'player_name', 'first_name', 'last_name', 'birth_date',
#        'height', 'weight', 'college', 'player_id', 'espn_id', 'sportradar_id',
#        'yahoo_id', 'rotowire_id', 'pff_id', 'pfr_id', 'fantasy_data_id',
#        'sleeper_id', 'years_exp', 'headshot_url', 'ngs_position', 'week',
#        'game_type', 'status_description_abbr', 'football_name', 'esb_id',
#        'gsis_it_id', 'smart_id', 'entry_year', 'rookie_year', 'draft_club',
#        'draft_number', 'age'],
#       dtype='object')
